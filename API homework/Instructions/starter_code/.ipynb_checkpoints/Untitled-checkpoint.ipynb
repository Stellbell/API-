# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key
from api_key_file import weather_api_key  

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 584

# %%
set = 1

for x in cities:
    print(x)
    city = x
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}" 
    print(url)

    weather_response= requests.get(url)
    data_json= weather_response.json()
    #if((x+1)%50 == 0): # for each set of 50 cities
       # time.sleep(60) # waits 1 minutes
      #  set += 1 # increases set number
         
    print(data_json)
# Out:
# atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 298.82, 'feels_like': 299.45, 'temp_min': 298.82, 'temp_max': 298.82, 'pressure': 1012, 'humidity': 77, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.38, 'deg': 35, 'gust': 6.09}, 'clouds': {'all': 6}, 'dt': 1640490873, 'sys': {'country': 'PF', 'sunrise': 1640444132, 'sunset': 1640489830}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.27, 'feels_like': 274.57, 'temp_min': 275, 'temp_max': 278.75, 'pressure': 1009, 'humidity': 98}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 295, 'gust': 3.13}, 'clouds': {'all': 90}, 'dt': 1640490873, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1640436228, 'sunset': 1640469022}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# east london
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 292.67, 'feels_like': 293.13, 'temp_min': 292.67, 'temp_max': 292.67, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 0}, 'rain': {'1h': 0.11}, 'clouds': {'all': 0}, 'dt': 1640490873, 'sys': {'type': 1, 'id': 1912, 'country': 'ZA', 'sunrise': 1640487547, 'sunset': 1640539112}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 300.18, 'feels_like': 302.77, 'temp_min': 300.18, 'temp_max': 300.18, 'pressure': 1013, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 90}, 'rain': {'1h': 1.73}, 'clouds': {'all': 20}, 'dt': 1640490874, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1640447807, 'sunset': 1640496115}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# lively
# http://api.openweathermap.org/data/2.5/weather?q=lively&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -81.1498, 'lat': 46.4334}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 272.05, 'feels_like': 267.95, 'temp_min': 271.14, 'temp_max': 273.6, 'pressure': 1010, 'humidity': 89, 'sea_level': 1010, 'grnd_level': 977}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 329, 'gust': 8.5}, 'clouds': {'all': 100}, 'dt': 1640490874, 'sys': {'type': 2, 'id': 2010755, 'country': 'CA', 'sunrise': 1640437623, 'sunset': 1640468546}, 'timezone': -18000, 'id': 6057842, 'name': 'Lively', 'cod': 200}
# mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 295.08, 'feels_like': 294.35, 'temp_min': 295.08, 'temp_max': 295.08, 'pressure': 1004, 'humidity': 39, 'sea_level': 1004, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 298, 'gust': 11.93}, 'clouds': {'all': 56}, 'dt': 1640490779, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1640451109, 'sunset': 1640507871}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 302.5, 'feels_like': 306.66, 'temp_min': 302.03, 'temp_max': 304.11, 'pressure': 1013, 'humidity': 70}, 'visibility': 8000, 'wind': {'speed': 2.68, 'deg': 10, 'gust': 0}, 'clouds': {'all': 20}, 'dt': 1640490607, 'sys': {'type': 2, 'id': 2037578, 'country': 'MY', 'sunrise': 1640474687, 'sunset': 1640517197}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# paita
# http://api.openweathermap.org/data/2.5/weather?q=paita&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -81.1144, 'lat': -5.0892}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 293.12, 'feels_like': 293.39, 'temp_min': 293.12, 'temp_max': 293.12, 'pressure': 1014, 'humidity': 85, 'sea_level': 1014, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 5.38, 'deg': 168, 'gust': 7.5}, 'clouds': {'all': 37}, 'dt': 1640490723, 'sys': {'country': 'PE', 'sunrise': 1640430728, 'sunset': 1640475424}, 'timezone': -18000, 'id': 3694112, 'name': 'Paita', 'cod': 200}
# chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 246.04, 'feels_like': 239.04, 'temp_min': 246.04, 'temp_max': 246.04, 'pressure': 1022, 'humidity': 97, 'sea_level': 1022, 'grnd_level': 1018}, 'visibility': 650, 'wind': {'speed': 4.38, 'deg': 253, 'gust': 7.89}, 'clouds': {'all': 100}, 'dt': 1640490875, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.03, 'feels_like': 298.58, 'temp_min': 298.03, 'temp_max': 298.03, 'pressure': 1011, 'humidity': 77, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.1, 'deg': 352, 'gust': 8.21}, 'rain': {'1h': 3.58}, 'clouds': {'all': 100}, 'dt': 1640490875, 'sys': {'country': 'PF', 'sunrise': 1640441612, 'sunset': 1640490399}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 268.06, 'feels_like': 261.06, 'temp_min': 268.06, 'temp_max': 268.06, 'pressure': 1017, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 9.26, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1640490875, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# andenes
# http://api.openweathermap.org/data/2.5/weather?q=andenes&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 16.1194, 'lat': 69.3143}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 268.14, 'feels_like': 262.61, 'temp_min': 268.14, 'temp_max': 268.14, 'pressure': 1005, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 160}, 'clouds': {'all': 91}, 'dt': 1640490876, 'sys': {'type': 1, 'id': 1603, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 3163146, 'name': 'Andenes', 'cod': 200}
# soe
# http://api.openweathermap.org/data/2.5/weather?q=soe&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 124.284, 'lat': -9.8607}, 'weather': [{'id': 503, 'main': 'Rain', 'description': 'very heavy rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 293.27, 'feels_like': 293.79, 'temp_min': 293.27, 'temp_max': 293.27, 'pressure': 1008, 'humidity': 94, 'sea_level': 1008, 'grnd_level': 915}, 'visibility': 9721, 'wind': {'speed': 1.84, 'deg': 298, 'gust': 6.78}, 'rain': {'1h': 27.34}, 'clouds': {'all': 100}, 'dt': 1640490876, 'sys': {'country': 'ID', 'sunrise': 1640467338, 'sunset': 1640513048}, 'timezone': 28800, 'id': 1626703, 'name': 'Soe', 'cod': 200}
# busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 307.6, 'feels_like': 306.86, 'temp_min': 307.6, 'temp_max': 307.6, 'pressure': 1013, 'humidity': 29, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 32, 'gust': 3.14}, 'clouds': {'all': 17}, 'dt': 1640490876, 'sys': {'country': 'AU', 'sunrise': 1640466456, 'sunset': 1640518227}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# belmonte
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -38.8828, 'lat': -15.8631}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.43, 'feels_like': 296.17, 'temp_min': 295.43, 'temp_max': 295.43, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 1.51, 'deg': 209, 'gust': 1.95}, 'clouds': {'all': 100}, 'dt': 1640490876, 'sys': {'type': 1, 'id': 8422, 'country': 'BR', 'sunrise': 1640505847, 'sunset': 1640552885}, 'timezone': -10800, 'id': 3470137, 'name': 'Belmonte', 'cod': 200}
# ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 283.96, 'feels_like': 282.51, 'temp_min': 283.96, 'temp_max': 283.96, 'pressure': 996, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1640490778, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1640505288, 'sunset': 1640567568}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 302.21, 'feels_like': 305.28, 'temp_min': 302.21, 'temp_max': 302.21, 'pressure': 1011, 'humidity': 66, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.8, 'deg': 282, 'gust': 3.15}, 'clouds': {'all': 68}, 'dt': 1640490877, 'sys': {'country': 'ID', 'sunrise': 1640473266, 'sunset': 1640517691}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# ponta delgada
# http://api.openweathermap.org/data/2.5/weather?q=ponta delgada&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -25.6667, 'lat': 37.7333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 291.55, 'feels_like': 291.74, 'temp_min': 291.55, 'temp_max': 292.32, 'pressure': 1005, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 11.83, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1640490877, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1640508988, 'sunset': 1640543398}, 'timezone': -3600, 'id': 3372783, 'name': 'Ponta Delgada', 'cod': 200}
# yilan
# http://api.openweathermap.org/data/2.5/weather?q=yilan&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 121.753, 'lat': 24.757}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.09, 'feels_like': 287.99, 'temp_min': 285.27, 'temp_max': 289.07, 'pressure': 1030, 'humidity': 90, 'sea_level': 1030, 'grnd_level': 1028}, 'visibility': 10000, 'wind': {'speed': 2.56, 'deg': 21, 'gust': 5.26}, 'clouds': {'all': 100}, 'dt': 1640490600, 'sys': {'type': 2, 'id': 2032887, 'country': 'TW', 'sunrise': 1640471716, 'sunset': 1640509885}, 'timezone': 28800, 'id': 1674199, 'name': 'Yilan', 'cod': 200}
# hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 290.23, 'feels_like': 289.14, 'temp_min': 288.29, 'temp_max': 293.72, 'pressure': 1013, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 225, 'gust': 4.47}, 'clouds': {'all': 0}, 'dt': 1640490583, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1640457056, 'sunset': 1640512264}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 292.19, 'feels_like': 292.6, 'temp_min': 292.19, 'temp_max': 292.19, 'pressure': 1012, 'humidity': 94, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 6.08, 'deg': 108, 'gust': 10.68}, 'clouds': {'all': 100}, 'dt': 1640490878, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1640489193, 'sunset': 1640541246}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# manitouwadge
# http://api.openweathermap.org/data/2.5/weather?q=manitouwadge&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -85.8403, 'lat': 49.1215}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 259.55, 'feels_like': 253.6, 'temp_min': 259.55, 'temp_max': 259.55, 'pressure': 1019, 'humidity': 83, 'sea_level': 1019, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 2.79, 'deg': 327, 'gust': 8.32}, 'clouds': {'all': 99}, 'dt': 1640490878, 'sys': {'type': 1, 'id': 185, 'country': 'CA', 'sunrise': 1640439424, 'sunset': 1640468997}, 'timezone': -18000, 'id': 6065253, 'name': 'Manitouwadge', 'cod': 200}
# kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -156.47, 'lat': 20.8947}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 295.54, 'feels_like': 295.95, 'temp_min': 294.24, 'temp_max': 296.74, 'pressure': 1014, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 19, 'gust': 5.81}, 'clouds': {'all': 34}, 'dt': 1640490878, 'sys': {'type': 2, 'id': 19170, 'country': 'US', 'sunrise': 1640451612, 'sunset': 1640490723}, 'timezone': -36000, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# lalomanu
# http://api.openweathermap.org/data/2.5/weather?q=lalomanu&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 260.43, 'feels_like': 253.43, 'temp_min': 260.43, 'temp_max': 260.43, 'pressure': 1015, 'humidity': 96, 'sea_level': 1015, 'grnd_level': 1011}, 'visibility': 216, 'wind': {'speed': 4.75, 'deg': 243, 'gust': 6.61}, 'snow': {'1h': 0.24}, 'clouds': {'all': 100}, 'dt': 1640490879, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# mitchell
# http://api.openweathermap.org/data/2.5/weather?q=mitchell&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -98.0298, 'lat': 43.7094}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 265.43, 'feels_like': 258.99, 'temp_min': 265.43, 'temp_max': 265.43, 'pressure': 1017, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 348, 'gust': 5.81}, 'clouds': {'all': 1}, 'dt': 1640490879, 'sys': {'type': 2, 'id': 2039694, 'country': 'US', 'sunrise': 1640441068, 'sunset': 1640473206}, 'timezone': -21600, 'id': 5229794, 'name': 'Mitchell', 'cod': 200}
# butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 301.07, 'feels_like': 304.47, 'temp_min': 301.07, 'temp_max': 301.07, 'pressure': 1007, 'humidity': 76, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 4.83, 'deg': 100, 'gust': 5.35}, 'rain': {'1h': 0.23}, 'clouds': {'all': 46}, 'dt': 1640490880, 'sys': {'country': 'KI', 'sunrise': 1640457049, 'sunset': 1640500046}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 254.03, 'feels_like': 247.03, 'temp_min': 253.44, 'temp_max': 254.49, 'pressure': 1019, 'humidity': 87}, 'visibility': 4828, 'wind': {'speed': 8.23, 'deg': 330}, 'snow': {'1h': 0.12}, 'clouds': {'all': 90}, 'dt': 1640490880, 'sys': {'type': 2, 'id': 2041581, 'country': 'CA', 'sunrise': 1640452090, 'sunset': 1640470022}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 292.48, 'feels_like': 292.79, 'temp_min': 291.98, 'temp_max': 292.48, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 4.99, 'deg': 97, 'gust': 8.45}, 'rain': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1640490880, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1640489405, 'sunset': 1640541421}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 295.26, 'feels_like': 295.59, 'temp_min': 295.26, 'temp_max': 295.26, 'pressure': 1005, 'humidity': 79, 'sea_level': 1005, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 5.61, 'deg': 237, 'gust': 8.12}, 'clouds': {'all': 65}, 'dt': 1640490880, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1640451132, 'sunset': 1640508102}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 57.7575, 'lat': -20.3428}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 299.29, 'feels_like': 299.29, 'temp_min': 299.29, 'temp_max': 301.05, 'pressure': 1015, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 340}, 'clouds': {'all': 20}, 'dt': 1640490881, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1640482117, 'sunset': 1640530211}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 270.18, 'feels_like': 263.18, 'temp_min': 269.42, 'temp_max': 270.79, 'pressure': 983, 'humidity': 91}, 'visibility': 4828, 'wind': {'speed': 7.72, 'deg': 310}, 'snow': {'1h': 0.79}, 'clouds': {'all': 90}, 'dt': 1640490881, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1640517517, 'sunset': 1640547864}, 'timezone': -12600, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# marsa matruh
# http://api.openweathermap.org/data/2.5/weather?q=marsa matruh&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 27.2453, 'lat': 31.3525}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 285.26, 'feels_like': 284.8, 'temp_min': 285.26, 'temp_max': 285.26, 'pressure': 1023, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 200}, 'clouds': {'all': 40}, 'dt': 1640490881, 'sys': {'type': 1, 'id': 2517, 'country': 'EG', 'sunrise': 1640495289, 'sunset': 1640531690}, 'timezone': 7200, 'id': 352733, 'name': 'Marsá Maţrūḩ', 'cod': 200}
# new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 289.66, 'feels_like': 288.28, 'temp_min': 287.54, 'temp_max': 293.52, 'pressure': 1016, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 246, 'gust': 4.92}, 'clouds': {'all': 29}, 'dt': 1640490881, 'sys': {'type': 2, 'id': 2031307, 'country': 'AU', 'sunrise': 1640457142, 'sunset': 1640512308}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# zeya
# http://api.openweathermap.org/data/2.5/weather?q=zeya&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 127.2667, 'lat': 53.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 251.02, 'feels_like': 251.02, 'temp_min': 251.02, 'temp_max': 251.02, 'pressure': 1024, 'humidity': 71, 'sea_level': 1024, 'grnd_level': 992}, 'visibility': 10000, 'wind': {'speed': 0.34, 'deg': 214, 'gust': 0.93}, 'clouds': {'all': 100}, 'dt': 1640490882, 'sys': {'country': 'RU', 'sunrise': 1640476094, 'sunset': 1640502859}, 'timezone': 32400, 'id': 2012593, 'name': 'Zeya', 'cod': 200}
# gwadar
# http://api.openweathermap.org/data/2.5/weather?q=gwadar&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 62.3254, 'lat': 25.1216}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 296.79, 'feels_like': 297.17, 'temp_min': 296.79, 'temp_max': 296.79, 'pressure': 1016, 'humidity': 75, 'sea_level': 1016, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 3.02, 'deg': 257, 'gust': 4.16}, 'clouds': {'all': 100}, 'dt': 1640490882, 'sys': {'country': 'PK', 'sunrise': 1640486028, 'sunset': 1640524107}, 'timezone': 18000, 'id': 1177446, 'name': 'Gwadar', 'cod': 200}
# hambantota
# http://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 81.1185, 'lat': 6.1241}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 299.34, 'feels_like': 299.34, 'temp_min': 299.34, 'temp_max': 299.34, 'pressure': 1015, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1640490882, 'sys': {'type': 1, 'id': 9124, 'country': 'LK', 'sunrise': 1640479375, 'sunset': 1640521737}, 'timezone': 19800, 'id': 1244926, 'name': 'Hambantota', 'cod': 200}
# najran
# http://api.openweathermap.org/data/2.5/weather?q=najran&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 44.1277, 'lat': 17.4924}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 288.51, 'feels_like': 286.91, 'temp_min': 288.51, 'temp_max': 288.51, 'pressure': 1018, 'humidity': 31, 'sea_level': 1018, 'grnd_level': 874}, 'visibility': 10000, 'wind': {'speed': 0.62, 'deg': 32, 'gust': 0.69}, 'clouds': {'all': 0}, 'dt': 1640490882, 'sys': {'type': 1, 'id': 7421, 'country': 'SA', 'sunrise': 1640489485, 'sunset': 1640529388}, 'timezone': 10800, 'id': 103630, 'name': 'Najrān', 'cod': 200}
# tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 244.15, 'feels_like': 237.15, 'temp_min': 244.15, 'temp_max': 244.15, 'pressure': 1022, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 150}, 'clouds': {'all': 1}, 'dt': 1640490883, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 0, 'sunset': 0}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# waipawa
# http://api.openweathermap.org/data/2.5/weather?q=waipawa&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 175.5153, 'lat': -41.4122}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 292.76, 'feels_like': 292.16, 'temp_min': 292.5, 'temp_max': 292.76, 'pressure': 1012, 'humidity': 53, 'sea_level': 1012, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 3.77, 'deg': 328, 'gust': 8.44}, 'clouds': {'all': 0}, 'dt': 1640490883, 'sys': {'type': 2, 'id': 2017525, 'country': 'NZ', 'sunrise': 1640450600, 'sunset': 1640505186}, 'timezone': 46800, 'id': 2206874, 'name': 'Waipawa', 'cod': 200}
# upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 257.2, 'feels_like': 250.2, 'temp_min': 257.2, 'temp_max': 257.2, 'pressure': 1015, 'humidity': 100, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 2155, 'wind': {'speed': 3.4, 'deg': 25, 'gust': 5.55}, 'clouds': {'all': 100}, 'dt': 1640490725, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -72.4167, 'lat': -35.3333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.89, 'feels_like': 289.37, 'temp_min': 289.89, 'temp_max': 289.89, 'pressure': 1013, 'humidity': 67, 'sea_level': 1013, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 2.73, 'deg': 195, 'gust': 3.9}, 'clouds': {'all': 8}, 'dt': 1640490883, 'sys': {'country': 'CL', 'sunrise': 1640511259, 'sunset': 1640563574}, 'timezone': -10800, 'id': 3893726, 'name': 'Constitución', 'cod': 200}
# pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -65.7125, 'lat': 66.1451}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 261.27, 'feels_like': 255.47, 'temp_min': 261.27, 'temp_max': 261.27, 'pressure': 1012, 'humidity': 70, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.93, 'deg': 55, 'gust': 2.36}, 'clouds': {'all': 7}, 'dt': 1640490884, 'sys': {'country': 'CA', 'sunrise': 1640444547, 'sunset': 1640454210}, 'timezone': -18000, 'id': 6096551, 'name': 'Pangnirtung', 'cod': 200}
# belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# bela
# http://api.openweathermap.org/data/2.5/weather?q=bela&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 81.9833, 'lat': 25.9333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 291.48, 'feels_like': 290.57, 'temp_min': 291.48, 'temp_max': 291.48, 'pressure': 1020, 'humidity': 46, 'sea_level': 1020, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.81, 'deg': 119, 'gust': 1.87}, 'clouds': {'all': 6}, 'dt': 1640490884, 'sys': {'country': 'IN', 'sunrise': 1640481413, 'sunset': 1640519284}, 'timezone': 19800, 'id': 1276574, 'name': 'Bela', 'cod': 200}
# half moon bay
# http://api.openweathermap.org/data/2.5/weather?q=half moon bay&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -122.4286, 'lat': 37.4636}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 280.98, 'feels_like': 280.52, 'temp_min': 279.6, 'temp_max': 282.38, 'pressure': 1009, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.34, 'deg': 168, 'gust': 5.36}, 'rain': {'1h': 0.12}, 'clouds': {'all': 75}, 'dt': 1640490884, 'sys': {'type': 2, 'id': 2037640, 'country': 'US', 'sunrise': 1640445750, 'sunset': 1640480240}, 'timezone': -28800, 'id': 5354943, 'name': 'Half Moon Bay', 'cod': 200}
# taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# san patricio
# http://api.openweathermap.org/data/2.5/weather?q=san patricio&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -97.5169, 'lat': 28.017}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 294.48, 'feels_like': 294.91, 'temp_min': 292.53, 'temp_max': 296.2, 'pressure': 1015, 'humidity': 86, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.95, 'deg': 166, 'gust': 10.23}, 'clouds': {'all': 7}, 'dt': 1640490885, 'sys': {'type': 2, 'id': 2040001, 'country': 'US', 'sunrise': 1640438354, 'sunset': 1640475674}, 'timezone': -21600, 'id': 4726521, 'name': 'San Patricio', 'cod': 200}
# turtas
# http://api.openweathermap.org/data/2.5/weather?q=turtas&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 69.1325, 'lat': 58.9417}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 252.36, 'feels_like': 245.36, 'temp_min': 252.36, 'temp_max': 252.36, 'pressure': 1032, 'humidity': 95, 'sea_level': 1032, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 2.81, 'deg': 172, 'gust': 8.52}, 'clouds': {'all': 6}, 'dt': 1640490885, 'sys': {'country': 'RU', 'sunrise': 1640492244, 'sunset': 1640514623}, 'timezone': 18000, 'id': 1540475, 'name': 'Turtas', 'cod': 200}
# gat
# http://api.openweathermap.org/data/2.5/weather?q=gat&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 34.7642, 'lat': 31.61}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 281.07, 'feels_like': 280.04, 'temp_min': 278.53, 'temp_max': 282.82, 'pressure': 1022, 'humidity': 63, 'sea_level': 1022, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.87, 'deg': 54, 'gust': 2.01}, 'clouds': {'all': 0}, 'dt': 1640490886, 'sys': {'type': 2, 'id': 2009987, 'country': 'IL', 'sunrise': 1640493521, 'sunset': 1640529848}, 'timezone': 7200, 'id': 293842, 'name': 'Kiryat Gat', 'cod': 200}
# ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 290.96, 'feels_like': 291.07, 'temp_min': 290.96, 'temp_max': 290.96, 'pressure': 1000, 'humidity': 87, 'sea_level': 1000, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 16.2, 'deg': 231, 'gust': 21.26}, 'clouds': {'all': 100}, 'dt': 1640490886, 'sys': {'country': 'PT', 'sunrise': 1640509851, 'sunset': 1640543991}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# kota belud
# http://api.openweathermap.org/data/2.5/weather?q=kota belud&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 116.4305, 'lat': 6.351}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 304.07, 'feels_like': 308.33, 'temp_min': 303.57, 'temp_max': 304.07, 'pressure': 1011, 'humidity': 62, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.81, 'deg': 357, 'gust': 2.22}, 'clouds': {'all': 100}, 'dt': 1640490886, 'sys': {'type': 1, 'id': 9371, 'country': 'MY', 'sunrise': 1640470921, 'sunset': 1640513235}, 'timezone': 28800, 'id': 1736660, 'name': 'Kota Belud', 'cod': 200}
# lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 287.08, 'feels_like': 286.85, 'temp_min': 287.08, 'temp_max': 287.08, 'pressure': 1017, 'humidity': 89, 'sea_level': 1017, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 8.25, 'deg': 182, 'gust': 14.95}, 'clouds': {'all': 0}, 'dt': 1640490886, 'sys': {'country': 'CL', 'sunrise': 1640511157, 'sunset': 1640564268}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?q=sao jose da coroa grande&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -35.1478, 'lat': -8.8978}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.6, 'feels_like': 299.5, 'temp_min': 298.6, 'temp_max': 298.6, 'pressure': 1011, 'humidity': 88, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.14, 'deg': 28, 'gust': 4.59}, 'rain': {'1h': 0.75}, 'clouds': {'all': 100}, 'dt': 1640490887, 'sys': {'country': 'BR', 'sunrise': 1640505718, 'sunset': 1640551220}, 'timezone': -10800, 'id': 3388456, 'name': 'São José da Coroa Grande', 'cod': 200}
# carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.19, 'feels_like': 301.99, 'temp_min': 300.19, 'temp_max': 300.19, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 280}, 'clouds': {'all': 96}, 'dt': 1640490887, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1640468132, 'sunset': 1640517367}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 294.59, 'feels_like': 295.06, 'temp_min': 294.59, 'temp_max': 294.59, 'pressure': 1012, 'humidity': 87, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 8.81, 'deg': 39, 'gust': 15.41}, 'clouds': {'all': 100}, 'dt': 1640490887, 'sys': {'country': 'ZA', 'sunrise': 1640487701, 'sunset': 1640539449}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# yeppoon
# http://api.openweathermap.org/data/2.5/weather?q=yeppoon&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 150.7333, 'lat': -23.1333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 300.03, 'feels_like': 302.71, 'temp_min': 300.03, 'temp_max': 300.03, 'pressure': 1008, 'humidity': 81, 'sea_level': 1008, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 2.08, 'deg': 106, 'gust': 2.7}, 'rain': {'1h': 0.56}, 'clouds': {'all': 100}, 'dt': 1640490887, 'sys': {'type': 1, 'id': 9499, 'country': 'AU', 'sunrise': 1640459449, 'sunset': 1640508237}, 'timezone': 36000, 'id': 2142316, 'name': 'Yeppoon', 'cod': 200}
# bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?q=pangkalanbuun&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 111.6167, 'lat': -2.6833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 305.39, 'feels_like': 309.01, 'temp_min': 305.39, 'temp_max': 305.39, 'pressure': 1010, 'humidity': 54, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.85, 'deg': 247, 'gust': 4.61}, 'clouds': {'all': 94}, 'dt': 1640490889, 'sys': {'country': 'ID', 'sunrise': 1640471138, 'sunset': 1640515330}, 'timezone': 25200, 'id': 1632694, 'name': 'Pangkalanbuun', 'cod': 200}
# ouadda
# http://api.openweathermap.org/data/2.5/weather?q=ouadda&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 22.4007, 'lat': 8.0777}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.74, 'feels_like': 295.7, 'temp_min': 296.74, 'temp_max': 296.74, 'pressure': 1011, 'humidity': 21, 'sea_level': 1011, 'grnd_level': 932}, 'visibility': 10000, 'wind': {'speed': 3.24, 'deg': 64, 'gust': 11.79}, 'clouds': {'all': 100}, 'dt': 1640490889, 'sys': {'country': 'CF', 'sunrise': 1640493677, 'sunset': 1640535629}, 'timezone': 3600, 'id': 236901, 'name': 'Ouadda', 'cod': 200}
# morden
# http://api.openweathermap.org/data/2.5/weather?q=morden&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -98.1014, 'lat': 49.1919}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 253.64, 'feels_like': 253.64, 'temp_min': 252.39, 'temp_max': 255.36, 'pressure': 1023, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 0.51, 'deg': 180}, 'clouds': {'all': 100}, 'dt': 1640490760, 'sys': {'type': 1, 'id': 674, 'country': 'CA', 'sunrise': 1640442386, 'sunset': 1640471922}, 'timezone': -21600, 'id': 6078447, 'name': 'Morden', 'cod': 200}
# jiuquan
# http://api.openweathermap.org/data/2.5/weather?q=jiuquan&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 98.5174, 'lat': 39.7432}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 261.38, 'feels_like': 257.55, 'temp_min': 261.38, 'temp_max': 261.38, 'pressure': 1045, 'humidity': 72, 'sea_level': 1045, 'grnd_level': 867}, 'visibility': 10000, 'wind': {'speed': 1.7, 'deg': 65, 'gust': 2.16}, 'clouds': {'all': 78}, 'dt': 1640490890, 'sys': {'country': 'CN', 'sunrise': 1640479531, 'sunset': 1640513227}, 'timezone': 28800, 'id': 1279945, 'name': 'Jiuquan', 'cod': 200}
# talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 254.93, 'feels_like': 247.93, 'temp_min': 254.93, 'temp_max': 254.93, 'pressure': 1033, 'humidity': 96, 'sea_level': 1033, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 3.78, 'deg': 125, 'gust': 4.83}, 'clouds': {'all': 97}, 'dt': 1640490890, 'sys': {'type': 2, 'id': 49144, 'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# roald
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 6.1333, 'lat': 62.5833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 275.03, 'feels_like': 270.79, 'temp_min': 271.55, 'temp_max': 276.23, 'pressure': 1009, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1640490890, 'sys': {'type': 1, 'id': 1602, 'country': 'NO', 'sunrise': 1640509672, 'sunset': 1640527445}, 'timezone': 3600, 'id': 3141667, 'name': 'Roald', 'cod': 200}
# lolua
# http://api.openweathermap.org/data/2.5/weather?q=lolua&appid=a66d6e9094774bfc52e92ab2184187bb
# {'cod': '404', 'message': 'city not found'}
# puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.57, 'feels_like': 295.22, 'temp_min': 294.57, 'temp_max': 294.57, 'pressure': 1014, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 194, 'gust': 3.58}, 'clouds': {'all': 82}, 'dt': 1640490891, 'sys': {'type': 2, 'id': 2005652, 'country': 'EC', 'sunrise': 1640433400, 'sunset': 1640477188}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 127.7558, 'lat': 26.1842}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.75, 'feels_like': 288.12, 'temp_min': 288.75, 'temp_max': 288.96, 'pressure': 1026, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 11.32, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1640490798, 'sys': {'type': 1, 'id': 8137, 'country': 'JP', 'sunrise': 1640470457, 'sunset': 1640508262}, 'timezone': 32400, 'id': 1855342, 'name': 'Nishihara', 'cod': 200}
# dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 248.15, 'feels_like': 241.15, 'temp_min': 248.15, 'temp_max': 248.15, 'pressure': 1026, 'humidity': 100, 'sea_level': 1026, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 3.29, 'deg': 155, 'gust': 3.45}, 'clouds': {'all': 18}, 'dt': 1640490892, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# volketswil
# http://api.openweathermap.org/data/2.5/weather?q=volketswil&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 8.6909, 'lat': 47.3902}, 'weather': [{'id': 612, 'main': 'Snow', 'description': 'shower sleet', 'icon': '13n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 278.07, 'feels_like': 276.95, 'temp_min': 275.58, 'temp_max': 279.57, 'pressure': 1005, 'humidity': 96}, 'visibility': 2900, 'wind': {'speed': 1.54, 'deg': 130}, 'snow': {'1h': 1}, 'clouds': {'all': 90}, 'dt': 1640490892, 'sys': {'type': 1, 'id': 6932, 'country': 'CH', 'sunrise': 1640502705, 'sunset': 1640533184}, 'timezone': 3600, 'id': 2658105, 'name': 'Volketswil / Volketswil (Dorf)', 'cod': 200}
# lima duarte
# http://api.openweathermap.org/data/2.5/weather?q=lima duarte&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -43.7931, 'lat': -21.8425}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 286.08, 'feels_like': 285.94, 'temp_min': 286.08, 'temp_max': 286.08, 'pressure': 1014, 'humidity': 96, 'sea_level': 1014, 'grnd_level': 929}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 51, 'gust': 1.93}, 'clouds': {'all': 58}, 'dt': 1640490892, 'sys': {'type': 2, 'id': 2037611, 'country': 'BR', 'sunrise': 1640506315, 'sunset': 1640554774}, 'timezone': -10800, 'id': 3458591, 'name': 'Lima Duarte', 'cod': 200}
# kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 301.67, 'feels_like': 306.04, 'temp_min': 301.67, 'temp_max': 301.67, 'pressure': 1007, 'humidity': 77, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 3.45, 'deg': 271, 'gust': 4.1}, 'rain': {'1h': 0.89}, 'clouds': {'all': 100}, 'dt': 1640490892, 'sys': {'country': 'PG', 'sunrise': 1640461743, 'sunset': 1640505912}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# vyskov
# http://api.openweathermap.org/data/2.5/weather?q=vyskov&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 16.999, 'lat': 49.2775}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 266.67, 'feels_like': 266.67, 'temp_min': 265.14, 'temp_max': 268.92, 'pressure': 1010, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 0.89, 'deg': 64, 'gust': 2.24}, 'clouds': {'all': 100}, 'dt': 1640490893, 'sys': {'type': 2, 'id': 2041369, 'country': 'CZ', 'sunrise': 1640501196, 'sunset': 1640530703}, 'timezone': 3600, 'id': 3062283, 'name': 'Vyškov', 'cod': 200}
# san quintin
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -115.95, 'lat': 30.4833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 287.74, 'feels_like': 287.19, 'temp_min': 287.74, 'temp_max': 287.74, 'pressure': 1018, 'humidity': 74, 'sea_level': 1018, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 4.84, 'deg': 308, 'gust': 6.17}, 'clouds': {'all': 97}, 'dt': 1640490893, 'sys': {'country': 'MX', 'sunrise': 1640443118, 'sunset': 1640479760}, 'timezone': -28800, 'id': 3984997, 'name': 'San Quintín', 'cod': 200}
# vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 302.24, 'feels_like': 309.06, 'temp_min': 302.24, 'temp_max': 302.24, 'pressure': 1012, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 250}, 'clouds': {'all': 75}, 'dt': 1640490893, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1640537944, 'sunset': 1640586242}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# hervey bay
# http://api.openweathermap.org/data/2.5/weather?q=hervey bay&appid=a66d6e9094774bfc52e92ab2184187bb
# ...
# sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -66.3821, 'lat': 50.2001}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 264.32, 'feels_like': 260.31, 'temp_min': 260.39, 'temp_max': 266.44, 'pressure': 1002, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 340}, 'clouds': {'all': 1}, 'dt': 1640490895, 'sys': {'type': 2, 'id': 2006302, 'country': 'CA', 'sunrise': 1640435050, 'sunset': 1640464028}, 'timezone': -18000, 'id': 6144312, 'name': 'Sept-Îles', 'cod': 200}
# ouallam
# http://api.openweathermap.org/data/2.5/weather?q=ouallam&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 2.0866, 'lat': 14.3188}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.05, 'feels_like': 293.66, 'temp_min': 295.05, 'temp_max': 295.05, 'pressure': 1012, 'humidity': 14, 'sea_level': 1012, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 4.05, 'deg': 49, 'gust': 5.13}, 'clouds': {'all': 100}, 'dt': 1640490896, 'sys': {'country': 'NE', 'sunrise': 1640499224, 'sunset': 1640539836}, 'timezone': 3600, 'id': 2440371, 'name': 'Ouallam', 'cod': 200}
# mbuji-mayi
# http://api.openweathermap.org/data/2.5/weather?q=mbuji-mayi&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 23.6, 'lat': -6.15}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 293.59, 'feels_like': 294.22, 'temp_min': 293.59, 'temp_max': 293.59, 'pressure': 1011, 'humidity': 97, 'sea_level': 1011, 'grnd_level': 945}, 'visibility': 10000, 'wind': {'speed': 0.38, 'deg': 79, 'gust': 0.44}, 'clouds': {'all': 98}, 'dt': 1640490896, 'sys': {'country': 'CD', 'sunrise': 1640491906, 'sunset': 1640536824}, 'timezone': 7200, 'id': 209228, 'name': 'Mbuji-Mayi', 'cod': 200}
# severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 272.81, 'feels_like': 265.81, 'temp_min': 272.81, 'temp_max': 272.81, 'pressure': 981, 'humidity': 97, 'sea_level': 981, 'grnd_level': 981}, 'visibility': 114, 'wind': {'speed': 12.72, 'deg': 82, 'gust': 17.96}, 'snow': {'1h': 1.08}, 'clouds': {'all': 100}, 'dt': 1640490896, 'sys': {'country': 'RU', 'sunrise': 1640468192, 'sunset': 1640496905}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# poum
# http://api.openweathermap.org/data/2.5/weather?q=poum&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 164.0167, 'lat': -20.2333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 301.04, 'feels_like': 304.26, 'temp_min': 301.04, 'temp_max': 301.04, 'pressure': 1008, 'humidity': 75, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.83, 'deg': 64, 'gust': 6.08}, 'clouds': {'all': 49}, 'dt': 1640490896, 'sys': {'country': 'NC', 'sunrise': 1640456619, 'sunset': 1640504688}, 'timezone': 39600, 'id': 2138555, 'name': 'Poum', 'cod': 200}
# egvekinot
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -179.1667, 'lat': 66.3167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 247.62, 'feels_like': 240.62, 'temp_min': 247.62, 'temp_max': 247.62, 'pressure': 1009, 'humidity': 88, 'sea_level': 1009, 'grnd_level': 951}, 'visibility': 10000, 'wind': {'speed': 4.79, 'deg': 8, 'gust': 5.43}, 'clouds': {'all': 100}, 'dt': 1640490896, 'sys': {'country': 'RU', 'sunrise': 1640558442, 'sunset': 1640567648}, 'timezone': 43200, 'id': 4031742, 'name': 'Egvekinot', 'cod': 200}
# bowen
# http://api.openweathermap.org/data/2.5/weather?q=bowen&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 148.2333, 'lat': -20.0167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 305.27, 'feels_like': 312.27, 'temp_min': 305.27, 'temp_max': 305.27, 'pressure': 1007, 'humidity': 67, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.33, 'deg': 348, 'gust': 4.35}, 'clouds': {'all': 100}, 'dt': 1640490897, 'sys': {'type': 1, 'id': 9503, 'country': 'AU', 'sunrise': 1640460435, 'sunset': 1640508451}, 'timezone': 36000, 'id': 2174444, 'name': 'Bowen', 'cod': 200}
# hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 140.8333, 'lat': 35.7333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 279.79, 'feels_like': 274.98, 'temp_min': 279.31, 'temp_max': 281.09, 'pressure': 1011, 'humidity': 35, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 9.74, 'deg': 320, 'gust': 10.12}, 'clouds': {'all': 74}, 'dt': 1640490897, 'sys': {'type': 1, 'id': 7955, 'country': 'JP', 'sunrise': 1640468687, 'sunset': 1640503752}, 'timezone': 32400, 'id': 2112802, 'name': 'Hasaki', 'cod': 200}
# makhachkala
# http://api.openweathermap.org/data/2.5/weather?q=makhachkala&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 47.5024, 'lat': 42.9764}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 270.14, 'feels_like': 264.29, 'temp_min': 270.14, 'temp_max': 270.14, 'pressure': 1020, 'humidity': 62, 'sea_level': 1020, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 5.29, 'deg': 158, 'gust': 7.81}, 'clouds': {'all': 42}, 'dt': 1640490897, 'sys': {'type': 1, 'id': 8965, 'country': 'RU', 'sunrise': 1640492400, 'sunset': 1640524852}, 'timezone': 10800, 'id': 532096, 'name': 'Makhachkala', 'cod': 200}
# hwange
# http://api.openweathermap.org/data/2.5/weather?q=hwange&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 26.5019, 'lat': -18.3693}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 293.74, 'feels_like': 294.26, 'temp_min': 293.74, 'temp_max': 293.74, 'pressure': 1014, 'humidity': 92, 'sea_level': 1014, 'grnd_level': 927}, 'visibility': 10000, 'wind': {'speed': 0.78, 'deg': 245, 'gust': 1.19}, 'rain': {'1h': 0.37}, 'clouds': {'all': 96}, 'dt': 1640490897, 'sys': {'country': 'ZW', 'sunrise': 1640489858, 'sunset': 1640537479}, 'timezone': 7200, 'id': 889942, 'name': 'Hwange', 'cod': 200}
# barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 250.89, 'feels_like': 243.89, 'temp_min': 250.89, 'temp_max': 250.89, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 9310, 'wind': {'speed': 5.03, 'deg': 87, 'gust': 6.92}, 'clouds': {'all': 100}, 'dt': 1640490898, 'sys': {'country': 'US', 'sunrise': 0, 'sunset': 0}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 241.4, 'feels_like': 235.06, 'temp_min': 241.4, 'temp_max': 241.4, 'pressure': 1034, 'humidity': 96, 'sea_level': 1034, 'grnd_level': 1030}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 143, 'gust': 1.47}, 'clouds': {'all': 63}, 'dt': 1640490898, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# nyimba
# http://api.openweathermap.org/data/2.5/weather?q=nyimba&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 30.8149, 'lat': -14.5566}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 293.19, 'feels_like': 293.68, 'temp_min': 293.19, 'temp_max': 293.19, 'pressure': 1014, 'humidity': 93, 'sea_level': 1014, 'grnd_level': 934}, 'visibility': 10000, 'wind': {'speed': 0.9, 'deg': 147, 'gust': 2.38}, 'clouds': {'all': 100}, 'dt': 1640490898, 'sys': {'country': 'ZM', 'sunrise': 1640489261, 'sunset': 1640536004}, 'timezone': 7200, 'id': 900056, 'name': 'Nyimba', 'cod': 200}
# tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 128.8694, 'lat': 71.6872}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 248.2, 'feels_like': 241.2, 'temp_min': 248.2, 'temp_max': 248.2, 'pressure': 1030, 'humidity': 100, 'sea_level': 1030, 'grnd_level': 1024}, 'visibility': 6505, 'wind': {'speed': 2.9, 'deg': 260, 'gust': 4.22}, 'clouds': {'all': 100}, 'dt': 1640490815, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 32400, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.73, 'feels_like': 275.06, 'temp_min': 272.31, 'temp_max': 281.08, 'pressure': 998, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 1.83, 'deg': 319, 'gust': 5.89}, 'clouds': {'all': 100}, 'dt': 1640490899, 'sys': {'type': 2, 'id': 2008903, 'country': 'US', 'sunrise': 1640434689, 'sunset': 1640467766}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.56, 'feels_like': 274.03, 'temp_min': 276.56, 'temp_max': 276.56, 'pressure': 1018, 'humidity': 89, 'sea_level': 1018, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.65, 'deg': 255, 'gust': 3.03}, 'clouds': {'all': 100}, 'dt': 1640490899, 'sys': {'country': 'US', 'sunrise': 1640458442, 'sunset': 1640481942}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -20.2734, 'lat': 63.4427}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 277.38, 'feels_like': 273.39, 'temp_min': 277.38, 'temp_max': 277.38, 'pressure': 1005, 'humidity': 77, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.28, 'deg': 77, 'gust': 6.35}, 'clouds': {'all': 100}, 'dt': 1640490899, 'sys': {'country': 'IS', 'sunrise': 1640516730, 'sunset': 1640533066}, 'timezone': 0, 'id': 3412093, 'name': 'Vestmannaeyjar', 'cod': 200}
# port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port macquarie&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 152.9167, 'lat': -31.4333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 300.87, 'feels_like': 302.72, 'temp_min': 300.87, 'temp_max': 301.13, 'pressure': 1011, 'humidity': 65, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 131, 'gust': 4.2}, 'clouds': {'all': 16}, 'dt': 1640490899, 'sys': {'type': 2, 'id': 2037918, 'country': 'AU', 'sunrise': 1640457778, 'sunset': 1640508859}, 'timezone': 39600, 'id': 2152659, 'name': 'Port Macquarie', 'cod': 200}
# ornes
# http://api.openweathermap.org/data/2.5/weather?q=ornes&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 13.7078, 'lat': 66.8689}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 266.35, 'feels_like': 262.55, 'temp_min': 265.39, 'temp_max': 266.95, 'pressure': 1005, 'humidity': 87, 'sea_level': 1005, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 142, 'gust': 1.76}, 'clouds': {'all': 100}, 'dt': 1640490900, 'sys': {'type': 1, 'id': 1615, 'country': 'NO', 'sunrise': 1640513416, 'sunset': 1640520064}, 'timezone': 3600, 'id': 3143368, 'name': 'Ørnes', 'cod': 200}
# plymouth
# http://api.openweathermap.org/data/2.5/weather?q=plymouth&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -70.8328, 'lat': 41.8334}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 274.94, 'feels_like': 270.68, 'temp_min': 272.8, 'temp_max': 276.89, 'pressure': 999, 'humidity': 96}, 'visibility': 1609, 'wind': {'speed': 4.63, 'deg': 330}, 'clouds': {'all': 90}, 'dt': 1640490900, 'sys': {'type': 2, 'id': 2002008, 'country': 'US', 'sunrise': 1640434159, 'sunset': 1640467056}, 'timezone': -18000, 'id': 4947607, 'name': 'Plymouth', 'cod': 200}
# terrace
# http://api.openweathermap.org/data/2.5/weather?q=terrace&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': -128.6035, 'lat': 54.5163}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 256.1, 'feels_like': 249.1, 'temp_min': 256.1, 'temp_max': 256.1, 'pressure': 1017, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 10, 'gust': 10.29}, 'clouds': {'all': 1}, 'dt': 1640490900, 'sys': {'type': 1, 'id': 984, 'country': 'CA', 'sunrise': 1640451373, 'sunset': 1640477581}, 'timezone': -28800, 'id': 6162949, 'name': 'Terrace', 'cod': 200}
# kitsuki
# http://api.openweathermap.org/data/2.5/weather?q=kitsuki&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 131.6167, 'lat': 33.4167}, 'weather': [{'id': 620, 'main': 'Snow', 'description': 'light shower snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 274.03, 'feels_like': 267.52, 'temp_min': 272.05, 'temp_max': 275.96, 'pressure': 1026, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.26, 'deg': 300, 'gust': 17.49}, 'clouds': {'all': 75}, 'dt': 1640490757, 'sys': {'type': 1, 'id': 8003, 'country': 'JP', 'sunrise': 1640470538, 'sunset': 1640506327}, 'timezone': 32400, 'id': 1859234, 'name': 'Kitsuki', 'cod': 200}
# jalu
# http://api.openweathermap.org/data/2.5/weather?q=jalu&appid=a66d6e9094774bfc52e92ab2184187bb
# {'coord': {'lon': 21.5482, 'lat': 29.0331}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 284.89, 'feels_like': 283.53, 'temp_min': 284.89, 'temp_max': 284.89, 'pressure': 1022, 'humidity': 54, 'sea_level': 1022, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 3.29, 'deg': 163, 'gust': 3.33}, 'clouds': {'all': 0}, 'dt': 1640490901, 'sys': {'country': 'LY', 'sunrise': 1640496332, 'sunset': 1640533383}, 'timezone': 7200, 'id': 86049, 'name': 'Jalu', 'cod': 200}
# mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=a66d6e9094774bfc52e92ab2184187bb

# %%
full_data = json.loads(full_payload)
df = json_normalize(full_data)

data_frame = df[['name', 'coord.lat', 'coord.lon', 'main.temp_max', 'main.humidity', 
                 'clouds.all', 'wind.speed','sys.country', 'dt']]

data_frame = data_frame.rename(columns={'name':'City', 'coord.lat':'Lat', 'coord.lon':'Lng', 'main.temp_max':'Max Temp', 
                           'main.humidity':'Humidity', 'clouds.all':'Cloudiness', 'wind.speed': 'Wind Speed',
                           'sys.country':'Country', 'dt':'Date'})      

data_frame.to_csv(path_or_buf='../output_data/cities.csv', index=False)

data_frame
